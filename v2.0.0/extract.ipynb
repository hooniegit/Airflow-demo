# %%
# 모듈 import
import requests, json

# %%
# requests informations
url = "http://kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieList.json?"
key = "bedea8450005818cf88ff722e915dd14"
page = 3

# %%
# url structure create
url_test = url + f"key={key}&itemPerPage=100&openStartDt=2023&curPage={page}"
print(url_test)
# Out:
# http://kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieList.json?key=bedea8450005818cf88ff722e915dd14&itemPerPage=100&openStartDt=2023&curPage=3

# %%
# get response
response = requests.get(url_test)
print(response.text)
# Out:
# {"movieListResult":{"totCnt":973,"source":"영화진흥위원회","movieList":[{"movieCd":"20217412","movieNm":"낭만적 공장","movieNmEn":"Punch-Drunk Love","prdtYear":"2022","openDt":"20230419","typeNm":"장편","prdtStatNm":"개봉","nationAlt":"한국","genreAlt":"멜로/로맨스","repNationNm":"한국","repGenreNm":"멜로/로맨스","directors":[{"peopleNm":"조은성"}],"companys":[{"companyCd":"20217189","companyNm":"크랭크업필름(주)"}]},{"movieCd":"20239884","movieNm":"우리 사랑이 향기로 남을 때","movieNmEn":"Love My Scent","prdtYear":"2022","openDt":"20230208","typeNm":"장편","prdtStatNm":"개봉","nationAlt":"한국","genreAlt":"멜로/로맨스,코미디,드라마","repNationNm":"한국","repGenreNm":"멜로/로맨스","directors":[{"peopleNm":"임성용"}],"companys":[{"companyCd":"20217665","companyNm":"(주)도깨비미디어"},{"companyCd":"20239668","companyNm":"주식회사 콘텐츠존"}]},{"movieCd":"20200154","movieNm":"킬링 로맨스","movieNmEn":"Killing Romance","prdtYear":"2021","openDt":"20230414","typeNm":"장편","prdtStatNm":"개봉","nationAlt":"한국","genreAlt":"코미디","repNationNm":"한국","repGenreNm":"코미디","directors":[{"peopleNm":"이원석"}],"companys":[{"companyCd":"20130188","companyNm":"(주)영화사 이창"},{"companyCd":"20230131","companyNm":"쇼트케이크(주)"}]},{"movieCd":"20226489","movieNm":"리바운드","movieNmEn":"Rebound","prdtYear":"2022","openDt":"20230405","typeNm":"장편","prdtStatNm":"개봉","nationAlt":"한국","genreAlt":"드라마","repNationNm":"한국","repGenreNm":"드라마","directors":[{"peopleNm":"장항준"}],"companys":[{"companyCd":"20138935","companyNm":"(주)비에이엔터테인먼트"},{"companyCd":"20230221","companyNm":"워크하우스컴퍼니(주)"}]},{"movieCd":"20226411","movieNm":"범죄도시3","movieNmEn":"THE ROUNDUP : NO WAY OUT","prdtYear":"2022","openDt":"20230531","typeNm":"장편","prdtStatNm":"개봉","nationAlt":"한국","genreAlt":"범죄,액션","repNationNm":"한국","repGenreNm":"범죄","directors":[{"peopleNm":"이상용"}],"companys":[{"companyCd":"20229048","companyNm":"주식회사 빅펀치픽쳐스"},{"companyCd":"20063279","companyNm":"(주)홍필름"},{"companyCd":"20138935","companyNm":"(주)비에이엔터테인먼트"}]},{"movieCd":"20232568","movieNm":"하얀봄","movieNmEn":"","prdtYear":"2023","openDt":"20230705","typeNm":"장편","prdtStatNm":"개봉","nationAlt":"한국","genreAlt":"공연","repNationNm":"한국","repGenreNm":"공연","directors":[{"peopleNm":"최진아"}],"companys":[{"companyCd":"20110019","companyNm":"한국문화예술위원회"}]},{"movieCd":"20232078","movieNm":"풍재기시","movieNmEn":"Where the Wind Blows","prdtYear":"2022","openDt":"20230705","typeNm":"장편","prdtStatNm":"개봉","nationAlt":"홍콩","genreAlt":"범죄,드라마","repNationNm":"홍콩","repGenreNm":"범죄","directors":[{"peopleNm":"옹자광"}],"companys":[]},{"movieCd":"20231923","movieNm":"엔니오: 더 마에스트로","movieNmEn":"Ennio","prdtYear":"2021","openDt":"20230705","typeNm":"장편","prdtStatNm":"개봉","nationAlt":"이탈리아","genreAlt":"다큐멘터리","repNationNm":"이탈리아","repGenreNm":"다큐멘터리","directors":[{"peopleNm":"쥬세페 토르나토레"}],"companys":[]},{"movieCd":"20226584","movieNm":"기적을 믿는 소녀","movieNmEn":"The Girl Who Believes in Miracles","prdtYear":"2021","openDt":"20230705","typeNm":"장편","prdtStatNm":"개봉","nationAlt":"미국","genreAlt":"드라마,가족","repNationNm":"미국","repGenreNm":"드라마","directors":[{"peopleNm":"리처드 코렐"}],"companys":[]},{"movieCd":"20230504","movieNm":"1986 그 여름, 그리고 고등어통조림","movieNmEn":"Sabakan","prdtYear":"2022","openDt":"20230705","typeNm":"장편","prdtStatNm":"개봉","nationAlt":"일본","genreAlt":"드라마,가족,코미디","repNationNm":"일본","repGenreNm":"드라마","directors":[],"companys":[]},{"movieCd":"20232500","movieNm":"맛이 다른 농염한 여직원의 흥건한 속살","movieNmEn":"","prdtYear":"2021","openDt":"20230704","typeNm":"장편","prdtStatNm":"개봉","nationAlt":"일본","genreAlt":"성인물(에로)","repNationNm":"일본","repGenreNm":"성인물(에로)","directors":[],"companys":[]},{"movieCd":"20232487","movieNm":"남편과 다른 삽입감, 쫀쫀한 불륜 유부녀","movieNmEn":"","prdtYear":"2021","openDt":"20230704","typeNm":"장편","prdtStatNm":"개봉","nationAlt":"일본","genreAlt":"성인물(에로)","repNationNm":"일본","repGenreNm":"성인물(에로)","directors":[{"peopleNm":"드래곤 니시카와"}],"companys":[]},{"movieCd":"20214823","movieNm":"유령","movieNmEn":"Phantom","prdtYear":"2022","openDt":"20230118","typeNm":"장편","prdtStatNm":"개봉","nationAlt":"한국","genreAlt":"드라마,액션","repNationNm":"한국","repGenreNm":"드라마","directors" ...

# %%
# 파일 저장
dir = f"/Users/kimdohoon/Desktop/movie/2023/KOBIS_MOVIE_LIST_2023_{page}.json"
with open (dir, "w", encoding="utf-8") as file:
    json.dump(response.json(), file, indent=4, ensure_ascii=False)
